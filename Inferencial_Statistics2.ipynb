# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -U kaleido
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##**Pearson Correlation Coefficient (r)**

# %% [markdown]
# ###**Two Columns**

# %%
#Pandas Dataframe
#Simple Correlation
import pandas as pd
import numpy as np


dataset = {'a': [10, 20, 30, 40, 50, 60, 70],
           'b': [20, 45, 55, 78, 82, 88, 95],
           'c': [10, 45, 67, 99, 98, 100, 120],
           'd': [15, 25, 33, 43, 54, 61, 71],
           'e': [140, 120, 55, 65, 44, 30, 3]
          }
df = pd.DataFrame(data=dataset)
column_0 = df["a"]
column_1 = df["b"]
column_2 = df["c"]
column_3 = df["d"]
column_4 = df["e"]

#Pearson Correlation
correlation1 = column_0.corr(column_1)
correlation2 = column_1.corr(column_2)
correlation3 = column_2.corr(column_3)
correlation4 = column_3.corr(column_4)

print("Correlation between a and b is: ", correlation1)
print("\n")
print("Correlation between b and c is: ", correlation2)
print("\n")
print("Correlation between c and d is: ", correlation3)
print("\n")
print("Correlation between d and e is: ", correlation4)
# Out:
# Correlation between a and b is:  0.9626543716854525
#
#
# Correlation between b and c is:  0.9922669819345395
#
#
# Correlation between c and d is:  0.9441724057015127
#
#
# Correlation between d and e is:  -0.9478394580145232

# %% [markdown]
# ###**More than Two Columns**

# %%
#Pandas Dataframe
#Correlation Matrix
import pandas as pd
import numpy as np


dataset = {'a': [10, 20, 30, 40, 50, 60, 70],
           'b': [20, 45, 55, 78, 82, 88, 95],
           'c': [10, 45, 67, 99, 98, 100, 120],
           'd': [15, 25, 33, 43, 54, 61, 71],
           'e': [140, 120, 55, 65, 44, 30, 3]
          }
df = pd.DataFrame(dataset) #pd.DataFrame(data=dataset)
correlation_df = df.corr()

print("\n")
print("Correlation Matrix for d to e: ")
print("\n")
print(correlation_df)
print("\n")

#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html
# Others are: kendall(Kendall Tau correlation coefficient)
#spearman (Spearman rank correlation)
correlation_df2 = df.corr(method = 'pearson')
print("\n")
print("Pearson Standard Correlation Coefficient")
print(correlation_df2)
# Out:
# Correlation Matrix for d to e:
#
#
#           a         b         c         d         e
# a  1.000000  0.962654  0.942664  0.999186 -0.952722
# b  0.962654  1.000000  0.992267  0.964684 -0.933838
# c  0.942664  0.992267  1.000000  0.944172 -0.939825
# d  0.999186  0.964684  0.944172  1.000000 -0.947839
# e -0.952722 -0.933838 -0.939825 -0.947839  1.000000
#
#
#
#
# Pearson Standard Correlation Coefficient
#           a         b         c         d         e
# a  1.000000  0.962654  0.942664  0.999186 -0.952722
# b  0.962654  1.000000  0.992267  0.964684 -0.933838
# c  0.942664  0.992267  1.000000  0.944172 -0.939825
# d  0.999186  0.964684  0.944172  1.000000 -0.947839
# e -0.952722 -0.933838 -0.939825 -0.947839  1.000000

# %% [markdown]
# ###**Using Panda.Series**

# %%
#Panda Series
#Simple Correlation
import pandas as pd
import numpy as np

a = pd.Series([10, 20, 30, 40, 50, 60, 70])
b = pd.Series([20, 45, 55, 78, 82, 88, 95])
c = pd.Series([10, 45, 67, 99, 98, 100, 120])
d = pd.Series([15, 25, 33, 43, 54, 61, 71])
e = pd.Series([140, 120, 55, 65, 44, 30, 3])

column_0 = a
column_1 = b
column_2 = c
column_3 = d
column_4 = e

#Pearson Correlation
correlation1 = column_0.corr(column_1).round(decimals=3)
correlation2 = column_1.corr(column_2).round(decimals=3)
correlation3 = column_2.corr(column_3).round(decimals=3)
correlation4 = column_3.corr(column_4).round(decimals=3)

print("Correlation between a and b is: ", correlation1)
print("\n")
print("Correlation between b and c is: ", correlation2)
print("\n")
print("Correlation between c and d is: ", correlation3)
print("\n")
print("Correlation between d and e is: ", correlation4)
# Out:
# Correlation between a and b is:  0.963
#
#
# Correlation between b and c is:  0.992
#
#
# Correlation between c and d is:  0.944
#
#
# Correlation between d and e is:  -0.948

# %% [markdown]
# ###**Heatmaps for Correlation**

# %% [markdown]
# ####**Heatmap without Label (or Annotation) and without Mask**

# %%
#Seaborn for correlation heatmaps without mask
#adapted from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#read in the pima-indians-diabetese.xlsx dataset
dataset = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/week3/pima-indians-diabetes.xlsx')
df = pd.DataFrame(dataset, columns=['pregNo', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age'])
print (df)

#create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
print("\n")
print("Pearson Standard Correlation Coefficient Matrix")
print(correlation)
print("\n")


#Set up matplotlib figure
f, ax = plt.subplots()   #figsize=(11, 9))

#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html
sns.set_style("white")

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
#      pregNo  glucose  bp  skin  insulin   bmi  pedigree  age
# 0         6      148  72    35        0  33.6     0.627   50
# 1         1       85  66    29        0  26.6     0.351   31
# 2         8      183  64     0        0  23.3     0.672   32
# 3         1       89  66    23       94  28.1     0.167   21
# 4         0      137  40    35      168  43.1     2.288   33
# ..      ...      ...  ..   ...      ...   ...       ...  ...
# 763      10      101  76    48      180  32.9     0.171   63
# 764       2      122  70    27        0  36.8     0.340   27
# 765       5      121  72    23      112  26.2     0.245   30
# 766       1      126  60     0        0  30.1     0.349   47
# 767       1       93  70    31        0  30.4     0.315   23
#
# [768 rows x 8 columns]
#
#
# Pearson Standard Correlation Coefficient Matrix
#             pregNo   glucose        bp      skin   insulin       bmi  \
# pregNo    1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683
# ...

# %% [markdown]
# ####**Heatmap without Label (or Annotation) and with Mask**

# %%
#Seaborn for correlation heatmaps with mask
#adapted from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#read in the pima-indians-diabetese.xlsx dataset
dataset = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/week3/pima-indians-diabetes.xlsx')
df = pd.DataFrame(dataset, columns= ['pregNo', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age'])
print (df)


#create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
print("\n")
print("Pearson Standard Correlation Coefficient Matrix")
print(correlation)
print("\n")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation, dtype=bool))


#Set up matplotlib figure
f, ax = plt.subplots()   #figsize=(11, 9))

#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html
sns.set_style("white")

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap without mask and correct aspect ratio
sns.heatmap(correlation, mask = mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
#      pregNo  glucose  bp  skin  insulin   bmi  pedigree  age
# 0         6      148  72    35        0  33.6     0.627   50
# 1         1       85  66    29        0  26.6     0.351   31
# 2         8      183  64     0        0  23.3     0.672   32
# 3         1       89  66    23       94  28.1     0.167   21
# 4         0      137  40    35      168  43.1     2.288   33
# ..      ...      ...  ..   ...      ...   ...       ...  ...
# 763      10      101  76    48      180  32.9     0.171   63
# 764       2      122  70    27        0  36.8     0.340   27
# 765       5      121  72    23      112  26.2     0.245   30
# 766       1      126  60     0        0  30.1     0.349   47
# 767       1       93  70    31        0  30.4     0.315   23
#
# [768 rows x 8 columns]
#
#
# Pearson Standard Correlation Coefficient Matrix
#             pregNo   glucose        bp      skin   insulin       bmi  \
# pregNo    1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683
# ...

# %% [markdown]
# ####**Heatmap with Label (or Annotation) and with Mask**

# %%
#Seaborn for correlation heatmaps with labels or annotations
#adapted from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#read in the pima-indians-diabetese.xlsx dataset
dataset = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/week3/pima-indians-diabetes.xlsx')
df = pd.DataFrame(dataset, columns= ['pregNo', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age'])
print (df)


#create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
print("\n")
print("Pearson Standard Correlation Coefficient Matrix")
print(correlation)
print("\n")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation, dtype=bool))


#Set up matplotlib figure
f, ax = plt.subplots()   #figsize=(11, 9))

#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html
sns.set_style("white")

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

#Turn on annotations for correlation values
#annot = True
#annot_kws = {"size": 12}

# Draw the heatmap without mask and correct aspect ratio
heatmap = sns.heatmap(correlation, mask = mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},
            annot = True, annot_kws = {"size": 10})

#Add ticks for labels
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

#Export heatmap as an image
heatmap.get_figure().savefig('heatmap_diabetes.png', bbox_inches='tight')
# Out:
#      pregNo  glucose  bp  skin  insulin   bmi  pedigree  age
# 0         6      148  72    35        0  33.6     0.627   50
# 1         1       85  66    29        0  26.6     0.351   31
# 2         8      183  64     0        0  23.3     0.672   32
# 3         1       89  66    23       94  28.1     0.167   21
# 4         0      137  40    35      168  43.1     2.288   33
# ..      ...      ...  ..   ...      ...   ...       ...  ...
# 763      10      101  76    48      180  32.9     0.171   63
# 764       2      122  70    27        0  36.8     0.340   27
# 765       5      121  72    23      112  26.2     0.245   30
# 766       1      126  60     0        0  30.1     0.349   47
# 767       1       93  70    31        0  30.4     0.315   23
#
# [768 rows x 8 columns]
#
#
# Pearson Standard Correlation Coefficient Matrix
#             pregNo   glucose        bp      skin   insulin       bmi  \
# pregNo    1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683
# ...

# %% [markdown]
# ####**Heatmap with Label (or Annotation) and with Mask**

# %%
#Seaborn for correlation heatmaps with labels or annotations
#adapted from https://seaborn.pydata.org/examples/many_pairwise_correlations.html
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week3/mobile.csv')
df = pd.DataFrame(dataset)
# print (df)

#create a correlation matrix for all the column sets except the target variable
correlation = df.corr()
# print("\n")
# print("Pearson Standard Correlation Coefficient Matrix")
# print(correlation)
# print("\n")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation, dtype=bool))


#Set up matplotlib figure
f, ax = plt.subplots(figsize=(25, 15))

#Set up a seaborn heatmap
#seaborne aesthetics https://seaborn.pydata.org/tutorial/aesthetics.html
sns.set_style("white")

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

#Turn on annotations for correlation values
#annot = True
#annot_kws = {"size": 12}

# Draw the heatmap with the mask and correct aspect ratio
heatmap = sns.heatmap(correlation, mask = mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5},
            annot = True, annot_kws = {"size": 10})

#Add ticks for labels
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

#Export heatmap as an image
heatmap.get_figure().savefig('mobile.png', bbox_inches='tight')

# %% [markdown]
# ###**n Top Variables that will have an Impact on another Variable**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import ExtraTreesClassifier

#read in dataset
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/week3/mobile.csv")
X = data.iloc[:,0:20]  #all rows for independent columns from Column 0 to 19, iloc => integer location
y = data.iloc[:, 20]    #all rows for target column i.e price range (Column 20)

#Build the model
model = ExtraTreesClassifier()
model.fit(X,y)

#Use inbuilt feature_importances of tree-based classifiers
print(model.feature_importances_)

#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)

#feat_importances.nlargest(10).plot(kind='barh')
feat_importances.nlargest(19).plot(kind='barh') #barh - horizontal bar chart
plt.show()
# Out:
# [0.05965528 0.01995218 0.0340767  0.01965535 0.03241183 0.01828411
#  0.03721766 0.03384078 0.03637075 0.03346928 0.03332797 0.04708674
#  0.04844768 0.38906519 0.03342674 0.03507487 0.03501259 0.01451591
#  0.01928841 0.01981998]

# %% [markdown]
# ###**Correlation Hypothesis Testing by using pvalues**

# %%
#Correlation Hypothesis Testing by using pvalues
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt

#Read data and build a dataframe
data = {'list 1':[2,4,6,8],'list 2':[4,16,36,64]}

df = pd.DataFrame(data, columns = ['list 1','list 2'])

#Calculate Pearson Correlation r and p value
pearson_coef_rvalue, p_value = stats.pearsonr(df["list 1"], df["list 2"]) #define the columns to perform calculations on
print("Pearson Correlation Coefficient r value : ", pearson_coef_rvalue.round(decimals=3), "and a P-value of:", p_value.round(decimals =3)) # Results
print("\n")
if (pearson_coef_rvalue == 0) :
  print('No Linear Relationship')
elif (pearson_coef_rvalue < 1 and pearson_coef_rvalue > 0.5):
  print('Strong Positive Relationship')
elif (pearson_coef_rvalue > 0.1 and pearson_coef_rvalue < 0.5):
  print('Weak Positive Relationship')
elif (pearson_coef_rvalue > -0.1 and pearson_coef_rvalue < 0.1):
  print('Almost No Relationship')
elif (pearson_coef_rvalue < -0.5 and pearson_coef_rvalue > -1):
  print('Strong Negative Relationship')
elif (pearson_coef_rvalue > -0.5 and pearson_coef_rvalue < -0.1):
  print('Weak Negative Relationship')
elif (pearson_coef_rvalue == 1):
  print('Perfect Positive Relationship')
else:
  print('Perfect Negative Relationship')
print("\n")

#Conduct Correlation Coefficient Hypothesis Testing
#Use 2 tail test
#Confidence level is 95%, alpha is 0.05 and alpha/2 is 0.025
alpha = 0.05
alpha_half = 0.025

if p_value > alpha_half:  # null hypothesis: x comes from a normal distribution
    print('Accept the null hypothesis: the conclusions are:')
    print('(i) correlation coefficient, r value, is equal to 0;')
    print('(ii) both variables are independent of each other;')
    print('(iii) both variables do not have any relationship')
else:
    print('Reject the null hypothesis: the conclusions are:')
    print('(i) correlation coefficient, r value, is significantly different from 0;')
    print('(ii) both variables are dependent of each other;')
    print('(iii) both variables have a relationship')
print("\n")

#Create Scatter Plot
plt.scatter(df["list 1"], df["list 2"])

#Add title and axis names
plt.title('A graph of list 1 against list 2')
plt.xlabel('list 1')
plt.ylabel('list 2')

# Show graphic
plt.show()
print("\n")
# Out:
# Pearson Correlation Coefficient r value :  0.984 and a P-value of: 0.016
#
#
# Strong Positive Relationship
#
#
# Reject the null hypothesis: the conclusions are:
# (i) correlation coefficient, r value, is significantly different from 0;
# (ii) both variables are dependent of each other;
# (iii) both variables have a relationship

# %%
#Correlation Coefficient (r) and Hypothesis Testing by using pvalues
import pandas as pd
from scipy import stats

#Read in the dataset
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week3/mobile.csv')
df = pd.DataFrame(dataset)  #df = pd.DataFrame(dataset, columns= ['#', '#'])
# print (df.head())

#Only explore 2 columns: Battery Power and Clock Speed
df1 = df['battery_power']
df2 = df['clock_speed']

#We would like to explore the relationship between Column 0 (battery_power) and Column 2(clock_speed)
pearson_coef_rvalue, p_value = stats.pearsonr(df1, df2) #define the columns to perform calculations on
print("Pearson Correlation Coefficient: ", pearson_coef_rvalue.round(decimals=3), "and a P-value of:", p_value.round(decimals=3)) # Results
print("\n")

if (pearson_coef_rvalue == 0) :
  print('No Linear Relationship')
elif (pearson_coef_rvalue < 1 and pearson_coef_rvalue > 0.5):
  print('Strong Positive Relationship')
elif (pearson_coef_rvalue > 0.1 and pearson_coef_rvalue < 0.5):
  print('Weak Positive Relationship')
elif (pearson_coef_rvalue > -0.1 and pearson_coef_rvalue < 0.1):
  print('Almost No Relationship')
elif (pearson_coef_rvalue < -0.5 and pearson_coef_rvalue > -1):
  print('Strong Negative Relationship')
elif (pearson_coef_rvalue > -0.5 and pearson_coef_rvalue < -0.1):
  print('Weak Negative Relationship')
elif (pearson_coef_rvalue == 1):
  print('Perfect Positive Relationship')
else:
  print('Perfect Negative Relationship')
print("\n")

#Conduct Correlation Coefficient Hypothesis Testing
#Use 2 tail test
#Confidence level is 98%, alpha is 0.05 and alpha/2 is 0.01
alpha = 0.02
alpha_half = 0.01

if p_value > alpha_half:  # null hypothesis: x comes from a normal distribution
    print('Accept the null hypothesis: the conclusions are:')
    print('(i) correlation coefficient, r value, is equal to 0;')
    print('(ii) both variables are independent of each other;')
    print('(iii) both variables do not have any relationship')
else:
    print('Reject the null hypothesis: the conclusions are:')
    print('(i) correlation coefficient, r value, is significantly different from 0;')
    print('(ii) both variables are dependent of each other;')
    print('(iii) both variables have a relationship')
print("\n")

#Create Scatter Plot
plt.scatter(df1, df2)

#Add title and axis names
plt.title('A graph of Battery Power against Clock Speed')
plt.xlabel('Battery Power')
plt.ylabel('Clock Speed')

# Show graphic
plt.show()
print("\n")
# Out:
# Pearson Correlation Coefficient:  0.011 and a P-value of: 0.608
#
#
# Almost No Relationship
#
#
# Accept the null hypothesis: the conclusions are:
# (i) correlation coefficient, r value, is equal to 0;
# (ii) both variables are independent of each other;
# (iii) both variables do not have any relationship

# %%
#https://machinelearningmastery.com/statistical-hypothesis-tests-in-python-cheat-sheet/
# Example of the Pearson's Correlation test
import pandas as pd
from scipy.stats import pearsonr

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]

df = pd.DataFrame(data, columns = ['data1','data2']) #<==


#Conduct Correlation Statistics
rvalue, pvalue = pearsonr(data1, data2)
print('Correlation stat = %.3f, pvalue = %.3f' % (rvalue, pvalue))
print("\n")

#Confedence level is 99%, alpha = 0.01
alpha_half = 0.005
if pvalue > alpha_half:
    print('Accept the null hypothesis: the conclusions are:')
    print('(i) correlation coefficient, r value, is equal to 0;')
    print('(ii) both variables are independent of each other;')
    print('(iii) both variables do not have any relationship')
else:
    print('Reject the null hypothesis: the conclusions are:')
    print('(i) correlation coefficient, r value, is significantly different from 0;')
    print('(ii) both variables are dependent of each other;')
    print('(iii) both variables have a relationship')
# Out:
# Correlation stat = 0.688, pvalue = 0.028
#
#
# Accept the null hypothesis: the conclusions are:
# (i) correlation coefficient, r value, is equal to 0;
# (ii) both variables are independent of each other;
# (iii) both variables do not have any relationship

# %% [markdown]
# ##**Chi Square**

# %% [markdown]
# ###**Goodness of Fit**

# %%
# Reference https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chisquare.html
# Chi Square Goodness Fit Test
from scipy.stats import chisquare

#Data for observed and expected frequencies from Monday to Sunday
f_obs = [110, 120, 230, 150, 170, 420, 300]
f_exp = [200, 200, 200, 200, 200, 250, 250]

#apply chisquare. ddof and axis is assumed to be 0.
chi_sqValue, pvalue = chisquare(f_obs, f_exp)
print("Chi Square value is: ", chi_sqValue)
print("P value is: ", pvalue)
print("\n")

#Confedence level is 98%, alpha = 0.02
alpha = 0.02 # one-tail test
if pvalue > alpha:
    print('Accept the null hypothesis: the conclusion is:')
    print('There is no significant difference between the observed and expected values.')
else:
    print('Reject the null hypothesis: the conclusion is:')
    print('There is a significant difference between the observed and expected values.')
# Out:
# Chi Square value is:  219.6
# P value is:  1.2663413447683768e-44
#
#
# Reject the null hypothesis: the conclusion is:
# There is a significant difference between the observed and expected values.

# %% [markdown]
# ###**Test of Independence**

# %%
#Crosstab, Contingency Table and Chi Square
import pandas as pd
import scipy.stats as stats

#read in the titanic.txt file
titanic = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/week3/titanic.txt")
# print(titanic.info()) #number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column
# print("\n")

# print(titanic.describe())
# print("\n")

print("Total number of males and females who survived in the dataset")
groupby_sex = titanic.groupby(["Sex", "Survived"]).size()
print(groupby_sex)
print("\n")

crosstab = pd.crosstab(titanic["Sex"], titanic["Survived"])
print(crosstab)
print("\n")

#To capture the relevant frequency values and store in variables
print("Total number of males and females who survived in the dataset")
a,b,c,d = titanic.groupby(["Sex", "Survived"]).size()
print("Number of females who died was:", a)
print("Number of females who survived was:", b)
print("Number of males who died was:", c)
print("Number of males who survived was:", d)
print("\n")

#Conduct the Chi Square Independence Test
#Interpretation https://www.pythonfordatascience.org/chi-square-test-of-independence-python/
#The information is returned within a tuple where the first value is the  test static,
#the second value is the p-value,
#and the third number is the degrees of freedom.
#An array is also returned which contains the expected cell counts.

w, x, y, z = stats.chi2_contingency(crosstab)
print("The Chi Square value is:", w)
print("The pvalue is:", x)
print("The value for degree of freedom is :", y)
print("Expected cell counts is:", z)
print("\n")

#Confedence level is 98%, alpha = 0.02
alpha = 0.02 # one-tail test
if x > alpha:
    print('Accept the null hypothesis: the conclusions are:')
    print('There is no significant difference between the observed and expected values.')
else:
    print('Reject the null hypothesis: the conclusions are:')
print('There is no significant difference between the observed and expected values.')
print("================================================================================================", "\n")

#Repeat the Chi Square Independence Test for the following table
print("Find the frequency count for grouped by sex (female and male), and  cabin class (Class 1, 2, 3)")
groupby_sex2 = titanic.groupby(["Sex", "Pclass"]).size()
crosstab2 = pd.crosstab(titanic["Sex"], titanic["Pclass"])
print(crosstab2)
print("\n")

k, l, m, n = stats.chi2_contingency(crosstab2)
print("The Chi Square value is:", k)
print("The pvalue is:", l)
print("The value for degree of freedom is :", m)
print("Expected cell counts is:", n)
print("\n")

#Confedence level is 98%, alpha = 0.02
alpha = 0.02 # one-tail test
if l > alpha:
    print('Accept the null hypothesis: the conclusions are:')
    print('There is no significant difference between the observed and expected values.')
else:
    print('Reject the null hypothesis: the conclusions are:')
    print('There is no significant difference between the observed and expected values.')
print("===============================================================================================", "\n")


#Repeat the Chi Square Independence Test for the following table
print("Find the frequency count for grouped by survived (0,1), and  cabin class (Class 1, 2, 3)")
groupby_sex3 = titanic.groupby(["Survived", "Pclass"]).size()
crosstab3 = pd.crosstab(titanic["Survived"], titanic["Pclass"])
print(crosstab3)
print("\n")

f, g, h, i = stats.chi2_contingency(crosstab3)
print("The Chi Square value is:", f)
print("The pvalue is:", g)
print("The value for degree of freedom is :", h)
print("Expected cell counts is:", i)
print("\n")

#Confedence level is 98%, alpha = 0.02
alpha = 0.02 # one-tail test
if g > alpha:
    print('Accept the null hypothesis: the conclusions are:')
    print('There is no significant difference between the observed and expected values.')
else:
    print('Reject the null hypothesis: the conclusions are:')
    print('There is no significant difference between the observed and expected values.')
print("===============================================================================================", "\n")


#Repeat the Chi Square Independence Test for the following table
print("Find the frequency count for grouped by sex (male, female), survived (0,1), and  cabin class (Class 1, 2, 3)")
crosstab4 = pd.crosstab(titanic["Sex"], [titanic["Survived"], titanic["Pclass"]])
print(crosstab4)
print("\n")

p, q, r, s = stats.chi2_contingency(crosstab4)
print("The Chi Square value is:", p)
print("The pvalue is:", q)
print("The value for degree of freedom is :", r)
print("Expected cell counts is:", s)
print("\n")

#Confedence level is 98%, alpha = 0.02
alpha = 0.02 # one-tail test
if q > alpha:
    print('Accept the null hypothesis: the conclusions are:')
    print('There is no significant difference between the observed and expected values.')
else:
    print('Reject the null hypothesis: the conclusions are:')
    print('There is no significant difference between the observed and expected values.')
# Out:
# Total number of males and females who survived in the dataset
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# dtype: int64
#
#
# Survived    0    1
# Sex
# female     81  233
# male      468  109
#
#
# Total number of males and females who survived in the dataset
# Number of females who died was: 81
# Number of females who survived was: 233
# Number of males who died was: 468
# Number of males who survived was: 109
#
#
# The Chi Square value is: 260.71702016732104
# The pvalue is: 1.1973570627755645e-58
# The value for degree of freedom is : 1
# Expected cell counts is: [[193.47474747 120.52525253]
#  [355.52525253 221.47474747]]
#
#
# Reject the null hypothesis: the conclusions are:
# There are relationships between the categorical variables.
# Knowing the value of one variable does help you predict the value of another variable.
# ...
#
# ...

# %% [markdown]
# ###**Shapiro-Wilks Test for Normal Distribution**

# %%
#Shapiro-Wilk Test
import pandas as pd
from scipy import stats

#read in the pima-indians-diabetese.xlsx dataset
dataset = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/week3/pima-indians-diabetes.xlsx')
df = pd.DataFrame(dataset, columns= ['pregNo', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age'])
print (df.head())

shapiro_test = stats.shapiro(df['age'])
print("\n")
print('The Overall Shapiro-Wilk Test Result is: ', shapiro_test)
print("\n")
print("The Shapiro Test Statistics value is: ",shapiro_test.statistic)
print("The Shapiro Test pvalue is: ",shapiro_test.pvalue)
print("\n")
#Conduct Shapiro-Wilk Hypothesis Testing
#Confidence level is 98%, alpha is 0.02
alpha = 0.02

if shapiro_test.pvalue < alpha:  # null hypothesis: x comes from a normal distribution
    print("Conclusion drawn: The null hypothesis can be rejected")
    print("Therefore reject the null hypothesis that age is drawn from a normal distribution")
else:
    print("Conclusion drawn: The null hypothesis is accepted")
    print("Therefor accept the null hypothesis that age is drawn from a normal distribution")
# Out:
#    pregNo  glucose  bp  skin  insulin   bmi  pedigree  age
# 0       6      148  72    35        0  33.6     0.627   50
# 1       1       85  66    29        0  26.6     0.351   31
# 2       8      183  64     0        0  23.3     0.672   32
# 3       1       89  66    23       94  28.1     0.167   21
# 4       0      137  40    35      168  43.1     2.288   33
#
#
# The Overall Shapiro-Wilk Test Result is:  ShapiroResult(statistic=0.874765932559967, pvalue=2.401829612553989e-24)
#
#
# The Shapiro Test Statistics value is:  0.874765932559967
# The Shapiro Test pvalue is:  2.401829612553989e-24
#
#
# Conclusion drawn: The null hypothesis can be rejected
# Therefore reject the null hypothesis that age is drawn from a normal distribution

# %% [markdown]
# ###**Quantile-Quantile (QQ) Plot for Normality**

# %%
# Quantile-Quantile (QQ) Plot for Normality
import pandas as pd
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot as plt


#Load the dataset
dataset = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/week3/pima-indians-diabetes.xlsx')
df = dataset['age']

# q-q plot for the age column, line = s is standardised line
qqplot(df, line='s')
plt.show()

# %% [markdown]
# ![QQ plot.png](data:image/png;base64,...)

# %% [markdown]
# ###**Levene Test for Equal Variances**

# %%
#	Levene Test for Equal Variances
# Levene's test is a statistical procedure for testing equality of variances
# (also sometimes called homoscedasticity or homogeneity of variances) between two or more samples
from scipy.stats import levene
a = [8.88, 9.12, 9.04, 8.98, 9.00, 9.08, 9.01, 8.85, 9.06, 8.99]
b = [8.88, 8.95, 9.29, 9.44, 9.15, 9.58, 8.36, 9.18, 8.67, 9.05]
c = [8.95, 9.12, 8.95, 8.85, 9.03, 8.84, 9.07, 8.98, 8.86, 8.98]
levene_test = levene(a, b, c)
print("The Levene Test Statistics value is: ", levene_test.statistic)
print("The Levene Test pvalue is: ", levene_test.pvalue)
print("\n")
# stat, p = levene(a, b, c)
# print(stat, p)

#Confidence level is 98%, alpha is 0.02
alpha = 0.02

if levene_test.pvalue < alpha:
    print("Conclusion drawn: The null hypothesis can be rejected")
    print("At least one of the k sample variances is not equal")
else:
    print("Conclusion drawn: The null hypothesis is accepted")
    print("All of the k samples have equal variances")
# Out:
# The Levene Test Statistics value is:  7.584952754501659
# The Levene Test pvalue is:  0.002431505967249681
#
#
# Conclusion drawn: The null hypothesis can be rejected
# At least one of the k sample variances is not equal

# %%
#	Levene Test for 3 columns in a dataset.
import pandas as pd
from scipy import stats
from scipy.stats import levene
import numpy as np

#read in the student marks file
dataset = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/week3/student_marks.xlsx")
print(dataset.head())

#Obtain the marks for Subjects 1, 2, 3
S1 = dataset['Subject1']
S2 = dataset['Subject2']
S3 = dataset['Subject3']
print("\n")
#Conduct Levene Test for Subjects 1, 2, 3
stat1, p1 = levene(S1, S2, S3, center = "mean")
print("Test using mean, pvalue =",p1)

stat2, p2 = levene(S1, S2, S3, center = "median")
print("Test using median, pvalue =", p2)
# Out:
#   Student_ID Group  Subject1  Subject2  Subject3  Subject4  Subject5
# 0        ID1     A        40        65        44        12        66
# 1        ID2     A        20        89        66        13        66
# 2        ID3     B        56        90        88        16        78
# 3        ID4     B        89        34        99        67        77
# 4        ID5     C        90        56        87        68        93
#
#
# Test using mean, pvalue = 0.8537498129240625
# Test using median, pvalue = 0.8600494878220108

# %%
#	Levene Test for subsets of dataset
import pandas as pd
from scipy import stats
from scipy.stats import levene
import numpy as np

#read in the student marks file
dataset = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/week3/student_marks.xlsx")
print(dataset.head())

#Obtain the marks for Subjects 1, 2, 3
S1 = dataset['Subject1']
S2 = dataset['Subject2']
S3 = dataset['Subject3']

print("\n")
#Conduct Levene Test for Subjects 1, 2, 3
stat1, p1 = levene(S1, S2, S3, center = "mean")
print("Test using mean ",p1)

stat2, p2 = levene(S1, S2, S3, center = "median")
print("Test using median ", p2)
print("\n")

Ga, Gb, Gc = dataset.groupby(['Group'])['Subject1']
# print(Ga)
# print(Gb)
# print(Gc)

groupA = dataset[dataset['Group'] == 'A']
print('Group A', groupA)
print("\n")

groupB = dataset[dataset['Group'] == 'B']
print('Group B', groupB)
print("\n")


groupC = dataset[dataset['Group'] == 'C']
print('Group C', groupC)
print("\n")

#Have to convert to List for Subject1
stat3, p3 = levene(list(groupA['Subject1']), list(groupB['Subject1']), list(groupC['Subject1']), center='mean')
stat4, p4 = levene(list(groupA['Subject1']), list(groupB['Subject1']), list(groupC['Subject1']), center='median')
print("Test using mean for Subject 1 for groups A, B, and C. The p value is: ",p3)
print("Test using median for Subject 1 for groups A, B, and C. The p value is: ",p4)
# Out:
#   Student_ID Group  Subject1  Subject2  Subject3  Subject4  Subject5
# 0        ID1     A        40        65        44        12        66
# 1        ID2     A        20        89        66        13        66
# 2        ID3     B        56        90        88        16        78
# 3        ID4     B        89        34        99        67        77
# 4        ID5     C        90        56        87        68        93
#
#
# Test using mean  0.8537498129240625
# Test using median  0.8600494878220108
#
#
# Group A    Student_ID Group  Subject1  Subject2  Subject3  Subject4  Subject5
# 0         ID1     A        40        65        44        12        66
# 1         ID2     A        20        89        66        13        66
# 6         ID7     A        23        67        34        98        12
# 7         ID8     A        50        23        39        96        20
# 12       ID13     A        89        65        87        46        64
# ...

# %% [markdown]
# ###**Mann Whiteney Test (Non-Parametric Alternative to the Two Sample T-Test )**

# %%
# Mann Whitney Test
import numpy as np
import scipy.stats as stats

# Create two groups of data
group1 = [1, 5 ,7 ,3 ,5 ,8 ,34 ,1 ,3 ,5 ,200, 3]
group2 = [10, 18, 11, 12, 15, 19, 9, 17, 1, 22, 9, 8]

# Calculate u and probability of a difference
u_statistic, pVal = stats.mannwhitneyu(group1, group2)

# Print results
print('P value:', pVal)
# Out:
# P value: 0.027761601509205928

# %%
# Mann Whitney Test
#Source
#https://techrando.com/2019/11/21/determine-if-two-distributions-are-significantly-different-using-the-mann-whitney-u-test/
import pandas as pd
import numpy as np
from scipy import stats

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week3/adult.csv', header = None)

#Declare the column names of the data set
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num',
              'marital-status', 'occupation', 'relationship',
              'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week',
              'native-country', 'salary']

df_less_than_50k = df[df['salary'] == ' <=50K']
df_greater_than_50k = df[df['salary'] == ' >50K']

u_statistic, p_value = stats.mannwhitneyu(list(df_less_than_50k['age']), list(df_greater_than_50k['age']))
# print(u_statistic, p_value)
print("The Mann Whitney Test Statistics value is: ",u_statistic)
print("The Mann Whitney Test pvalue is: ",p_value)
# Out:
# The Mann Whitney Test Statistics value is:  61203011.5
# The Mann Whitney Test pvalue is:  0.0
