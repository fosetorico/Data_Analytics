# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install -U kaleido
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
dataset.head(20)
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# ...

# %%
# import pandas as pd
# dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2_inferential/brain_size.csv', sep=';', na_values=".")
# dataset.describe

# %% [markdown]
# ###**Descriptive Statistics of Specific Columns**

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
dataset[["FSIQ", "VIQ", "Weight", "Height", "MRI_Count"]].describe()
# Out:
#              FSIQ         VIQ      Weight     Height     MRI_Count
# count   40.000000   40.000000   38.000000  39.000000  4.000000e+01
# mean   113.450000  112.350000  151.052632  68.525641  9.087550e+05
# std     24.082071   23.616107   23.478509   3.994649  7.228205e+04
# min     77.000000   71.000000  106.000000  62.000000  7.906190e+05
# 25%     89.750000   90.000000  135.250000  66.000000  8.559185e+05
# 50%    116.500000  113.000000  146.500000  68.000000  9.053990e+05
# 75%    135.500000  129.750000  172.000000  70.500000  9.500780e+05
# max    144.000000  150.000000  192.000000  77.000000  1.079549e+06

# %% [markdown]
# ###**Descriptive Statistics of Specific Columns Based on Grouping**

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
dataset[dataset['Gender'] == 'Female'][["FSIQ", "VIQ"]].describe()
# Out:
#              FSIQ         VIQ
# count   20.000000   20.000000
# mean   111.900000  109.450000
# std     23.686327   21.670924
# min     77.000000   71.000000
# 25%     90.250000   90.000000
# 50%    115.500000  116.000000
# 75%    133.000000  129.000000
# max    140.000000  136.000000

# %%
# import pandas as pd
# dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2_inferential/brain_size.csv', sep=';', na_values=".")
# groupby_gender = dataset.groupby('Gender')
# groupby_gender.describe()

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
groupby_gender = dataset.groupby('Gender')
df1 = groupby_gender.describe()
df_transposed = df1.T
df_transposed
# Out:
# Gender                   Female          Male
# Unnamed: 0 count      20.000000  2.000000e+01
#            mean       19.650000  2.135000e+01
#            std        11.356774  1.224863e+01
#            min         1.000000  2.000000e+00
#            25%        10.250000  1.150000e+01
#            50%        18.000000  2.150000e+01
#            75%        29.250000  3.225000e+01
#            max        38.000000  4.000000e+01
# FSIQ       count      20.000000  2.000000e+01
#            mean      111.900000  1.150000e+02
#            std        23.686327  2.498631e+01
#            min        77.000000  8.000000e+01
#            25%        90.250000  8.975000e+01
#            50%       115.500000  1.180000e+02
#            75%       133.000000  1.392500e+02
#            max       140.000000  1.440000e+02
# VIQ        count      20.000000  2.000000e+01
#            mean      109.450000  1.152500e+02
#            std        21.670924  2.564099e+01
# ...

# %% [markdown]
# ####**Transpositional Arrangement**

# %%
import pandas as pd

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
groupby_gender = dataset.groupby('Gender')
print("Mean by Gender")
print(groupby_gender.mean())
print("\n")

print("Median by Gender")
print(groupby_gender.median())
print("\n")

print("Describe FSIQ and VIQ  by Gender")
df1 = groupby_gender[['FSIQ','VIQ']].describe()
df_transposed = df1.T
print(df_transposed)
print("\n")

print("Skewness by Gender")
df2 = groupby_gender.skew()
df2_transposed = df2.T
print(df2_transposed)
print("\n")


print("Kurtosis by Gender")
df3 = pd.DataFrame(dataset)
print(df3.groupby('Gender').apply(pd.DataFrame.kurt))
print("\n")
# Out:
# Mean by Gender
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4
#
#
# Median by Gender
#         Unnamed: 0   FSIQ    VIQ    PIQ  Weight  Height  MRI_Count
# Gender
# Female        18.0  115.5  116.0  115.0   138.5    66.0   855365.0
# Male          21.5  118.0  110.5  117.0   172.0    70.5   947241.5
#
#
# Describe FSIQ and VIQ  by Gender
# Gender          Female        Male
# FSIQ count   20.000000   20.000000
#      mean   111.900000  115.000000
#      std     23.686327   24.986312
#      min     77.000000   80.000000
#      25%     90.250000   89.750000
#      50%    115.500000  118.000000
#      75%    133.000000  139.250000
#      max    140.000000  144.000000
# VIQ  count   20.000000   20.000000
#      mean   109.450000  115.250000
#      std     21.670924   25.640993
# ...

# %% [markdown]
# ####**Statistics based on Sub-Grouping**

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
print('\n')
print('Number of Females in the Dataset')
print(dataset[dataset['Gender'] == 'Female'].count())

print('\n')
print('Number of Males in the Dataset')
print(dataset[dataset['Gender'] == 'Male'].count())
# Out:
# Number of Females in the Dataset
# Unnamed: 0    20
# Gender        20
# FSIQ          20
# VIQ           20
# PIQ           20
# Weight        20
# Height        20
# MRI_Count     20
# dtype: int64
#
#
# Number of Males in the Dataset
# Unnamed: 0    20
# Gender        20
# FSIQ          20
# VIQ           20
# PIQ           20
# Weight        18
# Height        19
# MRI_Count     20
# dtype: int64

# %% [markdown]
# ##**T-Test**

# %% [markdown]
# ###**One-Sample T-Test**

# %%
import pandas as pd
from scipy import stats

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
stats.ttest_1samp(dataset['VIQ'], 0)

#ttest_1samp() statistical difference between a mean and a known or hypothesized value of the mean in the population
#df = Degree of Freedom
# Out:
# TtestResult(statistic=30.08809997084933, pvalue=1.3289196468727879e-28, df=39)

# %%
import pandas as pd
from scipy import stats

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
tvalue, pvalue = stats.ttest_1samp(dataset['VIQ'], 0)

#two-tail 2-sample t-test
alpha_half = 0.025   #alpha is 0.05 or level of confidence is 95%
print("p value = {:g}".format(pvalue))
print("t value = {:g}".format(tvalue))

if pvalue < alpha_half:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis is accepted")
# Out:
# p value = 1.32892e-28
# t value = 30.0881
# The null hypothesis can be rejected

# %% [markdown]
# ###**Two-Sample T-Test (Independent)**

# %%
import pandas as pd
from scipy import stats

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
female_fsiq = dataset[dataset['Gender'] == 'Female']['FSIQ']
male_fsiq = dataset[dataset['Gender'] == 'Male']['FSIQ']
stats.ttest_ind(female_fsiq, male_fsiq)
# Out:
# TtestResult(statistic=-0.4026724743703011, pvalue=0.6894456253897778, df=38.0)

# %%
import pandas as pd
from scipy import stats

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
female_fsiq = dataset[dataset['Gender'] == 'Female']['FSIQ']
male_fsiq = dataset[dataset['Gender'] == 'Male']['FSIQ']
# stats.ttest_ind(female_fsiq, male_fsiq)

tvalue, pvalue = stats.ttest_ind(female_fsiq, male_fsiq) #<====

#two-tail 2-sample t-test
alpha_half = 0.005   #alpha is 0.01 or level of confidence is 99%
print("p value = {:g}".format(pvalue))
print("t value = {:g}".format(tvalue))

if pvalue < alpha_half:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis is accepted")

#ttest_ind() a test for the null hypothesis that 2 independent samples have identical average (expected) values
# Out:
# p value = 0.689446
# t value = -0.402672
# The null hypothesis is accepted

# %% [markdown]
# ###**Two-Sample T-Test (Matched Pair)**

# %%
import pandas as pd
from scipy import stats

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
stats.ttest_rel(dataset['FSIQ'], dataset['PIQ'])

#ttest_rel() Calculates the T-test on TWO RELATED samples of scores, a and b
# Out:
# TtestResult(statistic=1.7842019405859857, pvalue=0.08217263818364236, df=39)

# %%
import pandas as pd
from scipy import stats

dataset = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/week2/brain_size.csv', sep=';', na_values=".")
tvalue, pvalue = stats.ttest_rel(dataset['FSIQ'], dataset['PIQ']) #<====

#two-tail 2-sample t-test
alpha_half = 0.01   #alpha is 0.02 or level of confidence is 98%
print("p value = {:g}".format(pvalue))
print("t value = {:g}".format(tvalue))

if pvalue < alpha_half:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis is accepted")
# Out:
# p value = 0.0821726
# t value = 1.7842
# The null hypothesis is accepted

# %% [markdown]
# ##**Anova**

# %% [markdown]
# ###**Box Plot**

# %%
import pandas as pd
from matplotlib import pyplot as plt

dataset = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/week2/score.xlsx")
print(dataset.describe())

dataset.boxplot(column=['A', 'B', 'C', 'D']) #, grid=False)
plt.title("Subject Scores")
plt.xlabel("Subjects")
plt.ylabel("Score")
# Out:
#                A          B          C          D
# count   5.000000   5.000000   5.000000   5.000000
# mean   29.600000  45.000000  31.200000  60.000000
# std     4.037326  11.202678   3.898718   8.514693
# min    25.000000  29.000000  27.000000  51.000000
# 25%    28.000000  40.000000  29.000000  54.000000
# 50%    29.000000  45.000000  30.000000  60.000000
# 75%    30.000000  55.000000  33.000000  62.000000
# max    36.000000  56.000000  37.000000  73.000000
# Text(0, 0.5, 'Score')

# %% [markdown]
# ###**One-Way Anova**

# %%
import pandas as pd
import scipy.stats as stats

dataset = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/week2/score.xlsx")
fvalue, pvalue = stats.f_oneway(dataset["A"], dataset["B"],dataset["C"], dataset["D"])
print("F Value  = {:g} ".format(fvalue))
print("P Value  = {:g} ".format(pvalue))

alpha = 0.05 # One-Tail Test

if pvalue < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis is accepted")
# Out:
# F Value  = 17.4928
# P Value  = 2.63924e-05
# The null hypothesis can be rejected

# %% [markdown]
# ###**Descriptive Statistics by Grouping**

# %%
import pandas as pd
import scipy.stats as stats

dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/week2/iris.csv")
groupby_name = dataset.groupby('name')
print(groupby_name.head())
print("\n")
print(groupby_name['petal_width'].describe())
print("\n")
df = groupby_name.describe()
df_transposed = df.T
print(df_transposed)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width        name
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# ...

# %%
import pandas as pd
import scipy.stats as stats

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/week2/iris.csv")
# fvalue, pvalue = stats.f_oneway(df['petal_width'][df['name'] == 'setosa'],
#                                 df['petal_width'][df['name'] == 'versicolor'],
#                                 df['petal_width'][df['name'] == 'virginica'])
df2 =(df['petal_width'][df['name'] == 'setosa'],
                       df['petal_width'][df['name'] == 'versicolor'],
                       df['petal_width'][df['name'] == 'virginica'])
fvalue, pvalue = stats.f_oneway(df2[0], df2[1], df2[2])
print("F Value  = {:g} ".format(fvalue))
print("P Value  = {:g} ".format(pvalue))

alpha = 0.05
if pvalue < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis is accepted")
# Out:
# F Value  = 959.324
# P Value  = 4.37696e-85
# The null hypothesis can be rejected

# %% [markdown]
# ###**One-Way Anova Table**

# %%
#https://www.statsmodels.org/stable/examples/notebooks/generated/interactions_anova.html
import pandas as pd
import scipy.stats as stats
from matplotlib import pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/week2/rehab.csv")

#Plot box plots grouped by Fitness - Groups 1, 2, 3
fig, ax = plt.subplots(figsize = (8,6))
fig = dataset.boxplot('Time', 'Fitness', ax = ax) #, grid=False)

#Sum of Square
sum_lm = ols('Time ~ Fitness', data=dataset).fit() # fit() calculate mean and SD

print(anova_lm(sum_lm), "\n")
print(anova_lm(sum_lm, typ=2), "\n")
print(anova_lm(sum_lm, typ=3))
# Out:
#             df      sum_sq     mean_sq          F    PR(>F)
# Fitness    1.0  666.216867  666.216867  34.749543  0.000006
# Residual  22.0  421.783133   19.171961        NaN       NaN
#
#               sum_sq    df          F    PR(>F)
# Fitness   666.216867   1.0  34.749543  0.000006
# Residual  421.783133  22.0        NaN       NaN
#
#                 sum_sq    df           F        PR(>F)
# Intercept  6679.707064   1.0  348.410223  5.611672e-15
# Fitness     666.216867   1.0   34.749543  6.230589e-06
# Residual    421.783133  22.0         NaN           NaN

# %% [markdown]
# ###**Two-Way Anova**

# %%
#https://plotly.com/python/v3/anova/
#Two Way ANOVA
#len - length of tooth,  supp - supplement, dose - dosage
import pandas as pd
import scipy.stats as stats
from matplotlib import pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

dataset = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/week2/tooth_growth.xlsx')
print(dataset.head())

fig, ax = plt.subplots(figsize=(8,6))
fig = dataset.boxplot('len', 'supp', ax = ax, grid=False)

formula = 'len ~ supp + dose + supp*dose'
model = ols(formula, dataset).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("\n")
print(anova_table)

# At a confidence level of 95% (or alpha = 0.05), the interaction between Supplement
# and Dose seems to have a significant effect on the length of the tooth (len)
# because the pvalue of 0.024 > alpha value of 0.05.
# Out:
#     len supp  dose
# 0   4.2   VC   0.5
# 1  11.5   VC   0.5
# 2   7.3   VC   0.5
# 3   5.8   VC   0.5
# 4   6.4   VC   0.5
#
#
#                 sum_sq    df           F        PR(>F)
# supp        205.350000   1.0   12.317020  8.936452e-04
# dose       2224.304298   1.0  133.415146  1.907985e-16
# supp:dose    88.920107   1.0    5.333483  2.463136e-02
# Residual    933.634929  56.0         NaN           NaN

# %% [markdown]
# # New Section
